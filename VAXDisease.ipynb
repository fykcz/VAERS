# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import os
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
vaxd = pd.read_excel('vaxgroups_with_disease.xlsx')
b = vaxd['DISEASE'].apply(lambda x : pd.Series(x.split(', '))).stack()
b_reset = b.reset_index()
vaxd_reset = vaxd.reset_index()
df_temp = pd.merge(b_reset,
                    vaxd_reset,
                    left_on = 'level_0',
                    right_on = 'index' )
disease_by_vax = df_temp[['VAX_TYPE', 0]]
disease_by_vax.rename(columns={0: "DISEASE"})
# Out:
#     VAX_TYPE       DISEASE
# 0     6VAX-F     Diptheria
# 1     6VAX-F       Tetanus
# 2     6VAX-F     Pertussis
# 3     6VAX-F         Polio
# 4     6VAX-F    HepatitisB
# ..       ...           ...
# 159      TYP       Typhoid
# 160      UNK       Unknown
# 161   VARCEL     Varicella
# 162   VARZOS     Varicella
# 163       YF  Yellow fever
#
# [164 rows x 2 columns]
